# %%
#Dependencies
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
#Read CSV
data_path="data.csv"
data=pd.read_csv(data_path)
data.drop(['type', 'species', 'coat', 'published_at', 'distance', 'search_address', 'search_city', 'search_state'], axis=1, inplace =True)
data.rename(columns={'Unnamed: 0':'dog_id'},inplace=True)
data.head()
# Out:
#    dog_id                                                url    age  gender  \
# 0       0  https://www.petfinder.com/dog/merry-lee-523247...  Adult  Female
# 1       1  https://www.petfinder.com/dog/cedric-52324702/...  Adult    Male
# 2       2  https://www.petfinder.com/dog/trooper-52324703...  Adult    Male
# 3       3  https://www.petfinder.com/dog/cyndi-52324704/g...  Adult  Female
# 4       4  https://www.petfinder.com/dog/enzo-52324705/ga...  Young    Male
#
#      size       name                  breeds.primary    breeds.secondary  \
# 0  Medium  Merry Lee              Labrador Retriever             Terrier
# 1   Large     Cedric                         Pointer    American Bulldog
# 2   Large    Trooper      Staffordshire Bull Terrier        Bull Terrier
# 3   Large      Cyndi  American Staffordshire Terrier                   0
# 4  Medium       Enzo                       Coonhound  Labrador Retriever
#
#    breeds.mixed  breeds.unknown  ... environment.cats  \
# ...

# %%
#Create Database Connection
from config import password
engine = create_engine(f'postgresql+psycopg2://postgres:{password}@localhost/Doghouse')
con = engine.connect()

# %%
#Load Data Frames into Database
data.to_sql(name='data', con=engine, if_exists='append', index=False)

# %%
#Confirm Data Frames are in Database
engine.table_names()
# Out:
# ['data']
